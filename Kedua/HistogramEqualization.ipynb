# %%
# %matplotlib inline
from IPython.display import display, Math, Latex
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open('fotbar.jpeg')
plt.imshow(img)

# %%
img = np.asanyarray(img)
img.shape
# Out:
# (1200, 1600, 3)

# %%
import cv2
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img.shape
# Out:
# (1200, 1600)

# %%
plt.imshow(img, cmap='gray')

# %%
flat = img.flatten()

# %%
plt.hist(flat, bins=50)
# Out:
# (array([6.37773e+05, 3.24829e+05, 1.63529e+05, 8.65540e+04, 6.97210e+04,
#         5.89020e+04, 5.46530e+04, 2.79120e+04, 5.34230e+04, 3.90070e+04,
#         3.28780e+04, 2.90290e+04, 2.66740e+04, 2.67910e+04, 1.37210e+04,
#         2.76440e+04, 2.50520e+04, 2.65740e+04, 2.18690e+04, 1.83570e+04,
#         1.14240e+04, 5.34000e+03, 1.13380e+04, 1.11450e+04, 9.39500e+03,
#         1.02430e+04, 9.30000e+03, 9.20300e+03, 4.12100e+03, 8.31900e+03,
#         7.82800e+03, 8.33200e+03, 7.95800e+03, 8.60600e+03, 6.23200e+03,
#         2.22200e+03, 3.32200e+03, 2.85500e+03, 2.69300e+03, 2.53200e+03,
#         2.64000e+03, 4.01000e+03, 2.55000e+03, 2.78600e+03, 5.03000e+02,
#         1.33000e+02, 5.00000e+01, 1.90000e+01, 6.00000e+00, 3.00000e+00]),
#  array([ 0.  ,  1.86,  3.72,  5.58,  7.44,  9.3 , 11.16, 13.02, 14.88,
#         16.74, 18.6 , 20.46, 22.32, 24.18, 26.04, 27.9 , 29.76, 31.62,
#         33.48, 35.34, 37.2 , 39.06, 40.92, 42.78, 44.64, 46.5 , 48.36,
#         50.22, 52.08, 53.94, 55.8 , 57.66, 59.52, 61.38, 63.24, 65.1 ,
#         66.96, 68.82, 70.68, 72.54, 74.4 , 76.26, 78.12, 79.98, 81.84,
#         83.7 , 85.56, 87.42, 89.28, 91.14, 93.  ]),
#  <BarContainer object of 50 artists>)

# %%
# create our own histogram function
def get_histogram(image, bins):
  # array with size of bins, set to zeros
  histogram = np.zeros(bins)
  # loop through pixels and sum up counts of pixels
  for pixel in image:
    histogram[pixel] += 1
    # return our final result
    return histogram
hist = get_histogram(flat, 256)
plt.plot(hist)
