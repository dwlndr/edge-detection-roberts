# %%
#Ardhilla Eka
#TI-2B

# memanggil library yang dibutuhkan
import cv2
from matplotlib import pyplot as plt

# %%
# Memuat gambar
imageObj = cv2.imread('cantik.jpg')

# %%
# untuk menghilangkan garis grid dan menampilkan gambar yang telah dimuat
plt.axis("off")
plt.title("Original Image")
plt.imshow(cv2.cvtColor(imageObj, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Menapatkan data RGB dari gambar
blue_color = cv2.calcHist([imageObj], [0], None, [256], [0, 256])
red_color = cv2.calcHist([imageObj], [1], None, [256], [0, 256])
green_color = cv2.calcHist([imageObj], [2], None, [256], [0, 256])

# %%
# Memisahkan histogram dari setiap warna
plt.subplot(3, 1, 1)
plt.title("histogram of Blue")
plt.hist(blue_color, color="blue")
  
plt.subplot(3, 1, 2)
plt.title("histogram of Green")
plt.hist(green_color, color="green")
  
plt.subplot(3, 1, 3)
plt.title("histogram of Red")
plt.hist(red_color, color="red")
  
# untuk mendapatkan tampilan yang jelas
plt.tight_layout()
plt.show()

# %%
# mengkombinasikan histogram dari semua warna RGB
plt.title("Histogram of all RGB Colors")
plt.hist(blue_color, color="blue")
plt.hist(green_color, color="green")
plt.hist(red_color, color="red")
plt.show()

# %%
#https://www.geeksforgeeks.org/visualizing-colors-in-images-using-histogram-in-python/

# %%
image = cv2.imread('cantik.jpg')

# %%
# convert the input image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# convert BGR to RGB to display using matplotlib
imgRGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.subplot(131),plt.imshow(imgRGB,cmap = 'gray'),plt.title('Original Image'), plt.axis('off')
plt.subplot(132),plt.imshow(gray,cmap = 'gray'),plt.title('Grayscale Image'),plt.axis('off')
plt.show()

# %%
dst = cv2.calcHist(gray, [0], None, [256], [0,256])

# %%
plt.hist(gray.ravel(),256,[0,256])
plt.title('Histogram for gray scale image')
plt.show()
